# %%
a = 6
a == 7
# Out:
# False

# %%
a = 6
a == 6
# Out:
# True

# %%
i = 5
i > 7
i >= 5
i!=6
# Out:
# True

# %%
"AC/DC" == "Michael Jackson"
"AC/DC"!="Michael Jackson"
# Out:
# True

# %%
age = 11
if (age > 18):
    print("you can enter")
print("move on")
# Out:
# move on

# %%
age = 17
if(age>=18):
    print("you can enter")
else:
    print("go too the Meat Loaf")
print("move on")
# Out:
# go too the Meat Loaf
# move on

# %%
age = 19
if(age>18):
    print("LETS GOOO")
elif(age==18):
    print("go see Pink Floyd")
else:
    print("go see Meat Loaf")
print("move on")
# Out:
# LETS GOOO
# move on

# %%
album_year = 1989
if(album_year < 1980) or (album_year > 1989):
    print("The Album was made in the 70s or 90s")
else:
    print("The album was made in the 1980s")
# Out:
# The album was made in the 1980s

# %%
album_year = 1983
if(album_year > 1979) and (album_year < 1990):
    print("The album was made in the 1980s")
else:
    print("The album was made in the 70 or 90")
# Out:
# The album was made in the 70 or 90

# %%
Annie = 1996 
Jane = 1999
if Annie%4==0:
    print("Annie born in a leap year")
elif Jane%4 == 0:
    print("Jane was born in a leap year")
else:
    print("Non of them")
# Out:
# Annie born in a leap year

# %%
age = 9
if age <=9:
    print ("You will get a milk")
elif age >= 10 and age <=14:
    print("sandwich")
elif age >= 115 and age<=17:
    print("burger")
# Out:
# You will get a milk

# %%
age = 25
if age == 25:
    print("25")
else:
    print("no")
# Out:
# 25

# %%
age = 25
if age != 30:
    print("you are not 30")
# Out:
# you are not 30

# %%
age = 20
if age >= 20:
    print("yes u older then 20")
# Out:
# yes u older then 20

# %%
age = 20
if age >= 21:
    print("you can enter")
else:
    print("no")
# Out:
# no

# %%
age = 21
if age >= 21:
    print("you can enter the bar")
elif age >= 18:
    print("go watch a movie")
else: 
    print("you cant")
# Out:
# you cant

# %%
user_choise = "Withdraw Cash"
if user_choise == "Withdraw Cash":
    amount = int(input("Enter the amount to withdraw: "))
    if amount% 10 ==0:
        print(("Here you are"))
    else: 
        print("Please enter a multiple of 10")
else:
    print("Thank you for using the ATM")
# Out:
# Here you are

# %%
if_do_not_distrub = True
if not if_do_not_distrub:
    send_notification("New message")

# %%
has_valid_id_card = True
has_valid_id_fingerprint = True
if has_valid_id_card and has_valid_id_fingerprint:
    open_high_secutity_door()
# Out:
#   Cell In[118], line 3
#     if has_valid_id_card and has_valid_id_fingerprint:
#                                                       ^
# _IncompleteInputError: incomplete input

# %%
score = 10
if score > 10:
    print('You need more points')
elif score == 10:
    print("Good job")
else:
    print("Too low")
# Out:
# Good job

# %%
score  = 43
if score > 90:
    print('Excellent')
elif score >= 60 and score <= 90:
    print('Good')
elif score < 60:
    print('Needs Improvement')
else:
    print("GJ")
# Out:
# Need Improvemet

# %%
i = 6
i < 5
# Out:
# False

# %%
'a' == 'A'
# Out:
# False

# %%
1=2
# Out:
#   Cell In[133], line 1
#     1=2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
