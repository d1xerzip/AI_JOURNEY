# %%
locations = {
    (49.895, -97.138): "Winnipeg",
    (43.653, -79.383): "Toronto",
    (49.282, -123.120): "Vancouver"
}
my_city = locations[(49.895, -97.138)]
print(my_city)
# Out:
# Winnipeg

# %%
coordinates = (10, 20, 30, 40, 50)
print(coordinates[1:4])
# Out:
# (20, 30, 40)

# %%
items = [1,2, [3, 'x'], [4, 'y']]
print(items[3][1])
operation = [1, 2, 3] + [4, 5, 6]
print(operation)
# Out:
# y
# [1, 2, 3, 4, 5, 6]

# %%
a = [1]
a.extend([2, 3, 4, 5])
len(a)
# Out:
# 5

# %%
a = (1, 2, 3, 4, 5)
print(a[1:4])
# Out:
# (2, 3, 4)

# %%
A = [1]
A.append([2,3,4,5])
len(A)
# Out:
# 2

# %%
# create dictionary with list, tuplesm etc
dict = {"Key1": 1, "Key2": "2", "key3": [3, 3, 3], "key4": (4, 4, 4), ('key5'): 5, (0,1): 6}
dict
# Access to the value
dict["Key1"]
# acces to the value by the key
dict[(0, 1)]
# Out:
# 6

# %%
release_year_dict = {"Thriller": 1982, "Back in Black": "1980", \
                    "The Dark Side of the Moon": "1973", "The Bodyguard": "1992", \
                    "Bat Out of Hell": "1977", "Their Greatest Hits (1971-1975)": "1976", \
                    "Saturday Night Fever": "1977", "Rumours": "1977"}
release_year_dict
release_year_dict['Thriller']
release_year_dict['The Bodyguard']
# get all the keys in dictionary
release_year_dict.keys()
#get all values in dictionary
release_year_dict.values()
#append
release_year_dict['Graduation'] ='2007'
release_year_dict
#delete
del(release_year_dict['Thriller'])
del(release_year_dict['Graduation'])
release_year_dict
'The Bodyguard' in release_year_dict
'Graduation' in release_year_dict
release_year_dict['Graduation'] = '2007'
release_year_dict
# Out:
# {'Back in Black': '1980',
#  'The Dark Side of the Moon': '1973',
#  'The Bodyguard': '1992',
#  'Bat Out of Hell': '1977',
#  'Their Greatest Hits (1971-1975)': '1976',
#  'Saturday Night Fever': '1977',
#  'Rumours': '1977',
#  'Graduation': '2007'}

# %%
# Sample
soundtrack_dic = {"The Bodyguard": "1992", "Saturday Night Fever":"1977"}
soundtrack_dic
soundtrack_dic.keys()
soundtrack_dic.values()
# Out:
# dict_keys(['The Bodyguard', 'Saturday Night Fever'])

# %%
album_sales_dict = {'Back in Back': 50, 'The Bodyguard': 50, 'Thriller': 65}
album_sales_dict
album_sales_dict['Thriller']
album_sales_dict.keys()
album_sales_dict.values()
print(album_sales_dict)
# Out:
# {'Back in Back': 50, 'The Bodyguard': 50, 'Thriller': 65}

# %%
inventory = {}
ProductNo1 = "Mobile Phone"
ProductNo1_quantity = 5
ProductNo1_price = 20000
ProductNo1_releaseYear = 2020
inventory["ProductNo1"] = ProductNo1
inventory["ProductNo1_quantity"] = ProductNo1_quantity
inventory["ProductNo1_price"] = ProductNo1_price
inventory["ProductNo1_releaseYear"] = ProductNo1_releaseYear
ProductNo2 = "Laptop"
ProductNo2_quantity = 10
ProductNo2_price = 50000
ProductNo2_releaseYear = 2023
inventory["ProductNo2"] = ProductNo2
inventory["ProductNo2_quantity"] = ProductNo2_quantity
inventory["ProductNo2_price"] = ProductNo2_price
inventory["ProductNo2_releaseYear"] = ProductNo2_releaseYear
print(inventory)
"ProductNo1_releaseYear" in inventory
print( "ProductNo1_releaseYear" in inventory)
print( "ProductNo2_releaseYear" in inventory)
del(inventory["ProductNo2_releaseYear"])
del(inventory["ProductNo1_releaseYear"])
inventory
# Out:
# {'ProductNo1': 'Mobile Phone', 'ProductNo1_quantity': 5, 'ProductNo1_price': 20000, 'ProductNo1_releaseYear': 2020, 'ProductNo2': 'Laptop', 'ProductNo2_quantity': 10, 'ProductNo2_price': 50000, 'ProductNo2_releaseYear': 2023}
# True
# True
# {'ProductNo1': 'Mobile Phone',
#  'ProductNo1_quantity': 5,
#  'ProductNo1_price': 20000,
#  'ProductNo2': 'Laptop',
#  'ProductNo2_quantity': 10,
#  'ProductNo2_price': 50000}

# %%
Home_storage = {}
thing1 = ["Apple"], ["Apple"]
thing1_color = ["red"], ["blue"]
thing1_quantity = [5], [7]
thing1_year = [2024], [2026]
Home_storage["thing1"] = thing1[0]
Home_storage["thing1_color"] = thing1_color[0]
Home_storage["thing1_quantity"] = thing1_quantity[0]
Home_storage["thing1_year"] = thing1_year[0]
print(Home_storage)
Home_storage
del(Home_storage['thing1_year'])
Home_storage["thing2"] = thing1[1]
Home_storage["thing2_color"] = thing1_color[1]
Home_storage["thing2_quantity"] = thing1_quantity[1]
Home_storage["thing2_year"] = thing1_year[1]
Home_storage
# Out:
# {'thing1': ['Apple'], 'thing1_color': ['red'], 'thing1_quantity': [5], 'thing1_year': [2024]}
# {'thing1': ['Apple'],
#  'thing1_color': ['red'],
#  'thing1_quantity': [5],
#  'thing2': ['Apple'],
#  'thing2_color': ['blue'],
#  'thing2_quantity': [7],
#  'thing2_year': [2026]}

# %%
Home_storage = {
    "thing1": {
        "name": "Apple",
        "color": "red",
        "quantity": 5
        # year мы удалили
    },
    "thing2": {
        "name": "Apple",
        "color": "blue",
        "quantity": 7,
        "year": 2026
    }
}

# %%
my_dict = {"a": 1, "b": 2}
my_dict["a"] # will be 1
keys_view = my_dict.keys()
keys_list = list(my_dict.keys())
print(keys_list)
# Out:
# ['a', 'b']

# %%
student = {"name": "Alice", "age": 24, "courses": ["Math", "Science"]}
courses = (student["courses"][0])
print(list(student.keys()))
print(list(student.values()))
list(student)
# Out:
# ['name', 'age', 'courses']
# ['Alice', 24, ['Math', 'Science']]
# ['name', 'age', 'courses']

# %%
Dict = {"A":1,"B":"2","C":[3,3,3],"D":(4,4,4),'E':5,'F':6}
Dict["D"]
# Out:
# (4, 4, 4)
