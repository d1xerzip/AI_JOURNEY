# %%
total_min = 43 + 42 + 57
print(total_min)
total_hr = total_min / 60
print(total_hr)
# Out:
# 142
# 2.3666666666666667

# %%
total__min = 196 - 12 + 25
total_hr = total_min/60
print(round(total_hr,2))
# Out:
# 2.37

# %%
total_hr = 3.7 * 61
total_min = total_hr * 60
print(f"In {round(total_min * 60, 2)} hours, will be {round(total_min, 2)} minutes")
# Out:
# In 812520.0 hours, will be 13542.0 minutes

# %%
total_min = (30+2) * 32
total_hr = total_min / 60
quoter = total_hr * (1 + 0.15)
print(f" Lets observe what happens if we increase {round(total_hr, 2)} hours by 15%")
print(f" With 15% increase, it will be {round(quoter, 2)} hours")
# Out:
#  Lets observe what happens if we increase 17.07 hours by 15%
#  With 15% increase, it will be 19.63 hours

# %%
total_min = "30 + 20 + 30" 
total_hr = eval(total_min) / 60
print(f" Total minuts is {eval(total_min)} and in hours it will be {round(total_hr,2)}")
# Out:
#  Total minuts is 80 and in hours it will be 1.33

# %%
minutes = [30, 20, 30]
total_min = sum(minutes)
total_hr = total_min / 60
print(f"Total hours: {total_hr:.2f}")
# Out:
# Total hours: 1.33

# %%
minutes = "30 + 20 + 21 + 44"
total_min = eval(minutes)
total_hr = total_min / 60
print(f"Total hours: {total_hr:.2f}")
print(f"Total minutes: {total_min} minutes")
# Out:
# Total hours: 1.92
# Total minutes: 115 minutes

# %%
minutes = 7
result = minutes // 2
print(f"{result}")
# Out:
# 3

# %%
minutes = "30 + 20 + 21 + 44"
total_min = eval(minutes)
total_hr = total_min / 60
print(f"Total hours: {round(total_min / 60)}")
print(f"Total minutes: {total_min} minutes")
# Out:
# Total hours: 2
# Total minutes: 115 minutes

# %%
minutes = "30 + 20 + 21 + 44"
total_min = eval(minutes)
total_hr = round(total_min / 60)
print(f"Total hours: {total_hr}")
print(f"Total minutes: {total_min} minutes")
# Out:
# Total hours: 2
# Total minutes: 115 minutes

# %%
minutes = "30 + 20 + 21 + 44"
total_min = eval(minutes)
total_hr = total_min / 60
print(f"Total hours: {round(total_hr, 2)}")
print(f"Total minutes: {total_min} minutes")
# Out:
# Total hours: 1.92
# Total minutes: 115 minutes

# %%
minutes = "30 + 20 + 21 + 44"
total_min = eval(minutes)
total_hr = total_min // 60
print(f"Total hours: {total_hr}")
print(f"Total minutes: {total_min} minutes")
# Out:
# Total hours: 1
# Total minutes: 115 minutes

# %%
x = 11
y = x // 2
print(f"{y}")
# Out:
# 5

# %%
x = 11
y = x / 2
print(f"{y}")
# Out:
# 5.5

# %%
x = 11
y = x / 2
print(f"{round(y, 2)}")
# Out:
# 5.5

# %%
x = 11
y = round(x / 2)
print(f"{y}")
# Out:
# 6
