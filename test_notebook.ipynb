# %%
name = "Artem"
print(f"Hello, {name}: This is my first Notebook. ")
# Out:
# Hello, Artem: This is my first Notebook.

# %%
price = 1700.50
count = 3
total = price * count
total
# Out:
# 5101.5

# %%
name = "Artem"
status = "is learning Jupyter"
print(f"{name} {status}!")
# Out:
# Artem is learning Jupyter!

# %%
price = 100
tax = 0.15
total = price * (1 + tax)
print(f"Total price with tax: {price + (price * tax) } USD")
# Out:
# Total price with tax: 115.0 USD

# %%
name = "artem"
print(f"Hello, {name.upper()}!") # Выведет: Hello, ARTEM!
# Out:
# Hello, ARTEM!

# %%
price = 200 
tax = 0.13
print(f"Option 1: {price + (price * tax)} USD")
print(f"Option 2: {price * 1.13} USD ")
print(f"Option 3: {round(price * 1.13, 2)} USD")
print(f"Option 2 rounded: {price *1.13:.2f} USD")
# Out:
# Option 1: 226.0 USD
# Option 2: 225.99999999999997 USD
# Option 3: 226.0 USD
# Option 2 rounded: 226.00 USD
