# %%
price = "$1250.50"
clean_price = price[1:] 
print(f"Clear price: {clean_price}") 
print(clean_price)
# Out:
# Clear price: 1250.50
# 1250.50

# %%
filename = "my_photo_of_michael.jpg"
extension = filename[-4:]
if extension  == ".jpg":
    print("AN IMAGE!")
else:
    print("Wrong format")
# Out:
# AN IMAGE!

# %%
user_id = "ID_99_Artem"
only_number = user_id[3:5]
print(f"User Id: {only_number}")
print(user_id[3])
# Out:
# User Id: 99
# 9

# %%
filename = "if_zalupa.png"
file_format = filename[-4:]
if file_format == ".png":
    print("Right ZALUPA")
else:
    print("Wrong Zalupa")
# Out:
# Right ZALUPA

# %%
name = "Artem Vladimirov"
print(name[0:])
# Out:
# Artem Vladimirov

# %%
count = 0
print(count)
count = count + 1
print(count)
count = count + 1
print(count)
# Out:
# 0
# 1
# 2

# %%
price = " $1250.5"
price = price.strip() #Price shows $1250.5 without spaces
price = price.replace("$", " ")
price = float(price)
print(price)
# Out:
# 1250.5

# %%
x = 5
x = x -2 
print(x)
# Out:
# 3

# %%
temperature = 30
new_temp = temperature - 4
print(new_temp)
# Out:
# 26

# %%
user_name = " $Artem "
without_dollar = user_name.replace("$", " ")
clean_name = without_dollar.strip()
name_length = len(clean_name)
print(name_length)
print(clean_name)
# Out:
# 5
# Artem

# %%
original_price = "$100"
clean__price = original_price.replace("$", " ")
print(clean__price)
# Out:
#  100

# %%
raw_password = "Zxccursed123"
clean_password =  raw_password.strip()
print(clean_password)

n
# Out:
# Zxccursed123
