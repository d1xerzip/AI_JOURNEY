# %%
Name = "Michael Jackson"
Name[0]: 'M'
Name[1]: 'i'
Name[2]: 'c'
Name[3]: 'h'
Name[4]: 'a'
Name[5]: 'e'
Name[6]: 'l'
Name[7]: ' '
Name[8]: 'J'
Name[9]: 'a'
Name[10]: 'c'
Name[11]: 'k'
Name[12]: 's'
Name[13]: 'o'
Name[14]: 'n'
print(Name[0])
# Out:
# M

# %%
Name = "Michael Jackson"
Name[0]: 'M'
Name[1]: 'i'
Name[2]: 'c'
Name[3]: 'h'
Name[4]: 'a'
Name[5]: 'e'
Name[6]: 'l'
Name[7]: ' '
Name[8]: 'J'
Name[9]: 'a'
Name[10]: 'c'
Name[11]: 'k'
Name[12]: 's'
Name[13]: 'o'
Name[14]: 'n'
print(f" His name is {Name[0:7]} and his surname is {Name[8:15]}")
# Out:
#  His name is Michael and his surname is Jackson

# %%
Name = "Michael Jackson"

print(Name[::2])
# Out:
# McalJcsn

# %%
Name = "Michael Jackson"
name_sum = Name[0] + Name[1] + Name[2] + Name[3] + Name[4] + Name[5] + Name[6]
name_sum_index = sum(range(len(Name)))
import math
indices = range(1, len(Name) + 1)
result = math.prod(indices)
total_product = 1
for i in range(1, len(Name) + 1):
    total_product = total_product * i
    a = "Michael Jackson is the best"
    b = a.replace("best", "geatest")

print(f"Im the {Name} u have {Name[::3]}")
print(len(Name))
print(Name[-1])
print(Name[2:5])
print(Name[0:7])
print(Name[::2])
print(f" sum of the each letter in the name and surname is {name_sum}")
print(f" sum of the each letter in the name and surname is {name_sum_index}")
print(f" Multiplication of the indices is {result}")
print(f" Multiplication of the indices is {total_product}")
print(f" name {Name} \n length of the name {len(Name)}")
print(f" name {Name} \t length of the name {len(Name)}")
print(f" name {Name} \\ length of the name {len(Name)}")
print(r" name {Name} \ length of the name {len(Name)}")
print(f" {Name.upper()}\n length of the name {len(Name)}")
print(b)
print(Name.find("el"))
print(Name.find("Jack"))
# Out:
# Im the Michael Jackson u have Mhlas
# 15
# n
# cha
# Michael
# McalJcsn
#  sum of the each letter in the name and surname is Michael
#  sum of the each letter in the name and surname is 105
#  Multiplication of the indices is 1307674368000
#  Multiplication of the indices is 1307674368000
#  name Michael Jackson
#  length of the name 15
#  name Michael Jackson 	 length of the name 15
#  name Michael Jackson \ length of the name 15
#  name {Name} \ length of the name {len(Name)}
#  MICHAEL JACKSON
#  length of the name 15
# Michael Jackson is the geatest
# 5
# 8

# %%
name = "John"
age = 30
print(f"My name is {name} and i am {age} years old")
print("My name is %s and im %d years old." %(name, age))
# Out:
# My name is John and i am 30 years old
# My name is John and im 30 years old.

# %%
qoantity = "5"
price = 10.5
print("Price for %s items is %.2f dollars" %(qoantity, price))
# Out:
# Price for 5 items is 10.50 dollars

# %%
regular_string = r"C:\Users\d1xer\OneDrive\Рабочий стол\AI JOURNEY"
print("Regular String: ", regular_string)
# Out:
# Regular String:  C:\Users\d1xer\OneDrive\Рабочий стол\AI JOURNEY

# %%
regular_string = "C:\\Users\\d1xer\\OneDrive\\Рабочий стол\\AI JOURNEY"
print("Regular String: ", regular_string)
# Out:
# Regular String:  C:\Users\d1xer\OneDrive\Рабочий стол\AI JOURNEY

# %%
import re

name = "Michael Jackson"
result = re.search(r"Michael", name)

print(name.split())
print(name.upper())
print(re.findall("a", name))
print(re.findall(name[3], name))
print(re.findall(r"[chael]", name))
print(re.findall(r"[Jackson]", name))
print(result)
# Out:
# ['Michael', 'Jackson']
# MICHAEL JACKSON
# ['a', 'a']
# ['h']
# ['c', 'h', 'a', 'e', 'l', 'a', 'c']
# ['c', 'a', 'J', 'a', 'c', 'k', 's', 'o', 'n']
# <re.Match object; span=(0, 7), match='Michael'>

# %%
name = "Artem Vladimirov"
result = re.search(r"Artem", name)
print(re.search("a", name))
# Out:
# <re.Match object; span=(8, 9), match='a'>

# %%
name = "Artem Vladimirov"
count_a = len(re.findall("a", name, re.IGNORECASE))
count_r = len(re.findall("r", name, re.IGNORECASE))
count_a = len(re.findall('[Aa]', name))
print (f" in name {name} u have {count_a} a's")
print (f" in name {name} u have {count_r} r's")
print(f"In name {name} u have {count_a} a's")
# Out:
#  in name Artem Vladimirov u have 2 a's
#  in name Artem Vladimirov u have 2 r's
# In name Artem Vladimirov u have 2 a's

# %%
s3 = "House number- 1105"
result = re.search(r"\d+", s3)
print(result)
# Out:
# <re.Match object; span=(14, 18), match='1105'>

# %%
s3 = "House number- 1105"
result = re.search(r"\d+", s3)
print(result)
print(f"Найденный номер: {result.group()}") # Выведет: 1105[cite: 8]
# Out:
# <re.Match object; span=(14, 18), match='1105'>
# Найденный номер: 1105

# %%
s3 = "House number- 1105"
result = re.search(r"\d+", s3)
print(result)
print(f"Найденный номер: {result}") # Выведет: 1105[cite: 8]
# Out:
# <re.Match object; span=(14, 18), match='1105'>
# Найденный номер: <re.Match object; span=(14, 18), match='1105'>

# %%
fullname = "Artem Vladimirov"
phonenumber = "1234567890"
name = re.findall(r"Artem", fullname)
lastname = re.findall(r"Vladimirov", fullname)
splited = (fullname.split())
combined_text = f"{fullname} {phonenumber}"
print(f"My name {name} and my last name {lastname}")
print(fullname.split()) 
print (f"Im trying to fidn just {re.findall(r"Artem", fullname)}")
print(splited)
print(re.findall(r"\d+", phonenumber))
print(re.search(r"\d", phonenumber))
print(re.search(r"\d+", phonenumber))
print(re.findall("a",fullname , re.IGNORECASE),)
print(len(re.findall("1", phonenumber)))
match = re.search(r"(\w+)\s(\w+)\s(\d+)", combined_text )
if match:
    name_only = match.group(1)
    lastname_only = match.group(2)
    phonenumber_only = match.group(3)
    print(f"name from group 1: {name_only}")
    print(f"surname from group 2: {lastname_only}")
    print(f"Phone from group 3: {phonenumber_only}")
print(f"My name is {match.group(1)} and my last name is {match.group(2)}, phone {phonenumber_only}")
print(re.findall(fullname[0], fullname, re.IGNORECASE))
print(Name[0])
print(fullname[0])
print(fullname [-1])
regular_string = "C:\\Users\\d1xer\\OneDrive\\Рабочий стол\\AI JOURNEY"
print("Regular String: ", regular_string)
# Out:
# My name ['Artem'] and my last name ['Vladimirov']
# ['Artem', 'Vladimirov']
# Im trying to fidn just ['Artem']
# ['Artem', 'Vladimirov']
# ['1234567890']
# <re.Match object; span=(0, 1), match='1'>
# <re.Match object; span=(0, 10), match='1234567890'>
# ['A', 'a']
# 1
# name from group 1: Artem
# surname from group 2: Vladimirov
# Phone from group 3: 1234567890
# My name is Artem and my last name is Vladimirov, phone 1234567890
# ['A', 'a']
# M
# A
# v
# Regular String:  C:\Users\d1xer\OneDrive\Рабочий стол\AI JOURNEY

# %%
price = "$1250.50"
clean_price = price[1:]
print(f"Clear price {clean_price}")
# Out:
# Clear price 1250.50

# %%
price = "$1250.50"
clean_price = price[2:]
print(f"Clear price {clean_price}")
# Out:
# Clear price 250.50

# %%
price = "$1250.50"
clean_price = price[3:]
print(f"Clear price {clean_price}")
# Out:
# Clear price 50.50

# %%
price = "$1250.50"
clean_price = price[:-4]
print(f"Clear price {clean_price}")
# Out:
# Clear price $125

# %%
price = "$1250.50"
clean_price = price[-1:]
print(f"Clear price {clean_price}")
# Out:
# Clear price 0

# %%
filename ="my_photo_of_michael.jpg"
extension = filename[-4:]
print(extension)
if extension == ".jpg"
# Out:
# .jpg
